# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# books = pd.read_csv('Desktop/okkk/ml/karooo/fire/bookssss/../Books.csv')
# users = pd.read_csv('Desktop/okkk/ml/karooo/fire/bookssss/data/Users.csv')
# ratings = pd.read_csv('Desktop/okkk/ml/karooo/fire/bookssss/data/Ratings.csv')

# %%
books = pd.read_csv('Desktop/okkk/ml/karooo/fire/bookssss/data/Books.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 books = pd.read_csv('Desktop/okkk/ml/karooo/fire/bookssss/data/Books.csv')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/okkk/ml/karooo/fire/bookssss/data/Books.csv'

# %%
sns.set_theme(
    style="whitegrid",
    font_scale=1.3,
    palette=['#21918c',"#4C72B0"], 
    rc={
        "text.color": "black",
        "axes.labelcolor": "black",
        "xtick.color": "black",
        "ytick.color": "black"
    }
)
palette_colors = ["#4C72B0", "#55A868", "#C44E52", "#8172B3"]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
# Book-Rating
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# Name: count, dtype: int64

# %%
print(books.shape)
print(users.shape)
print(ratings.shape)
# Out:
# (271360, 8)
# (278858, 3)
# (1149780, 3)

# %%
print(books.columns)
print(users.columns)
print(ratings.columns)
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')
# Index(['User-ID', 'Location', 'Age'], dtype='object')
# Index(['User-ID', 'ISBN', 'Book-Rating'], dtype='object')

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
print(books.duplicated().sum())
print(users.duplicated().sum())
print(ratings.duplicated().sum())
# Out:
# 0
# 0
# 0

# %%
def annotate_val_y(ax,fmt='.0f',gap=50):
    for p in ax.patches:
        width = p.get_width()
        y= p.get_y() +  p.get_height()/2

        ax.annotate(format(width,fmt),(width+gap,y), ha='left',va='center')

# %%
books1 = books.copy(deep=True)

# %%
books1['Year-Of-Publication'] = pd.to_numeric(books1['Year-Of-Publication'],errors='coerce').astype('Int64')

# %%
book_na_idx = books[books1['Year-Of-Publication'].isnull()].index

# %%
for i in book_na_idx :
    books.loc[i]['Year-Of-Publication'] , books.loc[i]['Book-Author'] = books.loc[i]['Book-Author'],books.loc[i]['Year-Of-Publication']

# %%
## The Top 15 Publishers

# %%
publisher = books['Publisher'].value_counts()[:15]
plt.figure(figsize=(15,10))
ax = plt.subplot(1,1,1)
sns.barplot(x=publisher.values,y=publisher.index,ax=ax)
annotate_val_y(ax)

# %%
author = books['Book-Author'].value_counts()[:15]
plt.figure(figsize=(15,10))
ax = plt.subplot(1,1,1)
sns.barplot(x=author.values,y=author.index,ax=ax)
annotate_val_y(ax, gap=5)

# %%
ratings= ratings['Book-Rating'].value_counts()
plt.pie(ratings.values, labels= ratings.index, autopct='%1.1f%%' ,startangle=90 )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Book-Rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 ratings= ratings['Book-Rating'].value_counts()
#       2 plt.pie(ratings.values, labels= ratings.index, autopct='%1.1f%%' ,startangle=90 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:1130, in Series.__getitem__(self, key)
#    1127     return self._values[key]
#    1129 elif key_is_scalar:
# -> 1130     return self._get_value(key)
#    1132 # Convert generator to list before going through hashable part
#    1133 # (We will iterate through the generator there to check for slices)
#    1134 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:1246, in Series._get_value(self, label, takeable)
#    1243     return self._values[label]
#    1245 # Similar to Index.get_value, but we do not fall back to positional
# -> 1246 loc = self.index.get_loc(label)
#    1248 if is_integer(loc):
#    1249     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Book-Rating'

# %% [markdown]
# ## Popularity based

# %%
rat_book = ratings.merge(books,on='ISBN')

# %%
num_ratings = rat_book.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_ratings.rename(columns={'Book-Rating' : 'num_rating'},inplace=True)

# %%
avg_ratings = rat_book.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_ratings.rename(columns={'Book-Rating' : 'avg_rating'},inplace=True)

# %%
popular_df = avg_ratings.merge(num_ratings,on='Book-Title')

# %%
popular_df = popular_df[popular_df['num_rating']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title
# 39          510              Harper Lee     Little Brown &amp; Company
# 47          898               Dan Brown                      Doubleday
# 53          430             Mitch Albom                       Hyperion
# 55          449           J.D. Salinger                  Little, Brown
# 62         1295            Alice Sebold                  Little, Brown
# 63          284           George Orwell                    Signet Book
# 72          253      Barbara Kingsolver                      Perennial
# 73          265             Neil Gaiman                           Avon
# 78          774           Sue Monk Kidd                  Penguin Books
# 84          283           Michael Moore                    Regan Books
# 85          493             MITCH ALBOM                      Doubleday
# 88          723           Anita Diamant                    Picador USA
# 89          268           Douglas Adams                         Pocket
# 98          335      Barbara Ehrenreich                      Owl Books
# 100         252            Jon Krakauer                         Anchor
# 103         409            Ray Bradbury                Distribooks Inc
# 116         526         Tracy Chevalier                    Plume Books
# 117         283          DIANA GABALDON                           Dell
# 123         585            Billie Letts                   Warner Books
# 124         275       LAURA HILLENBRAND               Ballantine Books
# 126         664             Yann Martel                       Harcourt
# 130         389      Barbara Kingsolver                      Perennial
# 133         265             Dave Pelzer          Health Communications
# 135         279           Frank McCourt                       Scribner
# 137         490         Jennifer Weiner        Washington Square Press
# 139         321          Eric Schlosser                      Perennial
# 140         302             Neil Gaiman                    HarperTorch
# 141         322            JOHN GRISHAM                      Doubleday
# 147         318              Tim Lahaye       Tyndale House Publishers
# 149         336          PHILIP PULLMAN  Knopf Books for Young Readers
# 157         314            Alice Walker                   Pocket Books
# 163         256           Thomas Harris             St. Martin's Press
# 166         262             Nick Hornby                Riverhead Books
# 173         278         Janet Evanovich             St. Martin's Press
# 175         266            Paulo Coelho             HarperSanFrancisco
# 177         269         Janet Evanovich        St. Martin's Paperbacks
# 182         457         James Patterson                  Little, Brown
# 186         259  William Gerald Golding                  Perigee Trade
# 192         413             John Irving               Ballantine Books
# 194         301               ANNE RICE               Ballantine Books
# 195         356             Janet Fitch                 Back Bay Books
#
#     Year-Of-Publication                                        Image-URL-M
# 0                  1999  http://images.amazon.com/images/P/0439136350.0...
# 3                  2000  http://images.amazon.com/images/P/0439139597.0...
# 5                  1998  http://images.amazon.com/images/P/0590353403.0...
# 9                  2003  http://images.amazon.com/images/P/043935806X.0...
# 13                 2000  http://images.amazon.com/images/P/0439064872.0...
# 16                 1986  http://images.amazon.com/images/P/0345339681.0...
# 17                 1986  http://images.amazon.com/images/P/0345339703.0...
# 26                 1999  http://images.amazon.com/images/P/059035342X.0...
# 28                 1986  http://images.amazon.com/images/P/0345339711.0...
# 39                 1988  http://images.amazon.com/images/P/0446310786.0...
# 47                 2003  http://images.amazon.com/images/P/0385504209.0...
# 53                 2003  http://images.amazon.com/images/P/0786868716.0...
# 55                 1991  http://images.amazon.com/images/P/0316769487.0...
# 62                 2002  http://images.amazon.com/images/P/0316666343.0...
# 63                 1990  http://images.amazon.com/images/P/0451524934.0...
# 72                 2001  http://images.amazon.com/images/P/0060959037.0...
# 73                 1998  http://images.amazon.com/images/P/0380789019.0...
# 78                 2003  http://images.amazon.com/images/P/0142001740.0...
# 84                 2002  http://images.amazon.com/images/P/0060392452.0...
# 85                 1997  http://images.amazon.com/images/P/0385484518.0...
# 88                 1998  http://images.amazon.com/images/P/0312195516.0...
# 89                 1982  http://images.amazon.com/images/P/0671461494.0...
# 98                 2002  http://images.amazon.com/images/P/0805063897.0...
# 100                1997  http://images.amazon.com/images/P/0385486804.0...
# 103                1994  http://images.amazon.com/images/P/3257208626.0...
# 116                2001  http://images.amazon.com/images/P/0452282152.0...
# 117                1996  http://images.amazon.com/images/P/0440222915.0...
# 123                1998  http://images.amazon.com/images/P/0446672211.0...
# 124                2002  http://images.amazon.com/images/P/0449005615.0...
# 126                2002  http://images.amazon.com/images/P/0151008116.0...
# 130                1989  http://images.amazon.com/images/P/0060915544.0...
# 133                1995  http://images.amazon.com/images/P/1558743669.0...
# 135                1996  http://images.amazon.com/images/P/0684874350.0...
# 137                2002  http://images.amazon.com/images/P/0743418174.0...
# 139                2002  http://images.amazon.com/images/P/0060938455.0...
# 140                2002  http://images.amazon.com/images/P/0380789035.0...
# 141                2001  http://images.amazon.com/images/P/0385505833.0...
# 147                1996  http://images.amazon.com/images/P/0842329129.0...
# 149                2002  http://images.amazon.com/images/P/037582345X.0...
# 157                1985  http://images.amazon.com/images/P/0671617028.0...
# 163                1991  http://images.amazon.com/images/P/0312924585.0...
# 166                1999  http://images.amazon.com/images/P/1573227331.0...
# 173                2001  http://images.amazon.com/images/P/0312265840.0...
# 175                1993  http://images.amazon.com/images/P/0062502174.0...
# 177                2003  http://images.amazon.com/images/P/0312983867.0...
# 182                2001  http://images.amazon.com/images/P/0316969443.0...
# 186                1959  http://images.amazon.com/images/P/0399501487.0...
# 192                1990  http://images.amazon.com/images/P/0345361792.0...
# 194                1986  http://images.amazon.com/images/P/0345313860.0...
# 195                2000  http://images.amazon.com/images/P/0316284955.0...

# %%
## Collaborative

# %%
x = rat_book.groupby('User-ID')['Book-Rating'].count() >200
user_index = list(x[x].index)

# %%
filter_rating = rat_book[rat_book['User-ID'].isin(user_index)]

# %%
y = filter_rating.groupby('Book-Title')['Book-Rating'].count() >= 50
book_index = y[y].index

# %%
filter_rating = filter_rating[filter_rating['Book-Title'].isin(book_index)]

# %%
pt = filter_rating.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating').fillna(0)

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             2977    3363    4017    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             4385    6251    6323    \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             6543    ...  271705  \
# Book-Title                                                  ...
# 1984                                                   0.0  ...    10.0
# 1st to Die: A Novel                                    9.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# User-ID                                             273979  274004  274061  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        9.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# User-ID                                             274301  274308  275970  \
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    8.0     0.0     0.0
#
# User-ID                                             277427  277639  278418
# Book-Title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [706 rows x 810 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(pt)

# %%
def recommend(book):
    idx = np.where(pt.index==book)[0][0]
    distance = similarity[idx]
    book_list = sorted(list(enumerate(distance)),reverse=True, key = lambda x: x[1])[1:6]

    data=[]
    for i in book_list :
        item =[]
        # print (pt.index[i[0]])
        temp_df = books[books['Book-Title']==pt.index[i[0]]].drop_duplicates('Book-Title')
        # print(temp_df)
        item.extend(temp_df['Book-Title'].values)
        item.extend(temp_df['Book-Author'].values)
        item.extend(temp_df['Image-URL-M'].values)

        data.append(item)
    return data

# %%
recommend("Harry Potter and the Chamber of Secrets (Book 2)")
# Out:
# [['Harry Potter and the Prisoner of Azkaban (Book 3)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Goblet of Fire (Book 4)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg'],
#  ["Harry Potter and the Sorcerer's Stone (Book 1)",
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg'],
#  ['Harry Potter and the Order of the Phoenix (Book 5)',
#   'J. K. Rowling',
#   'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg']]

# %%
import pickle

# %%
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(similarity, open('similarity.pkl','wb'))
pickle.dump(books , open('book.pkl','wb'))
